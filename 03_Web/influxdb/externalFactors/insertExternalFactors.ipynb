# %%
from influxdb_client import InfluxDBClient, Point
from influxdb_client.client.write_api import SYNCHRONOUS
import csv
from datetime import datetime

# %%
url = "http://tradehunter.duckdns.org:8086"
token = "KYrAp2dOqBHVBNr0XIT--Rm_PaSF2sWP_b7YZO-QD9MCPuejpe0Dzu7j3-6mxSK7xcCbVWJJYHdVgFdAQHbEFw=="
org = "Trade Hunter"
bucket = "Trade Hunter Real Time Data"

# %%
#Initialize the InfluxDB client
client = InfluxDBClient(url=url, token=token, org=org)
#Initialize the synchronous write API
write_api = client.write_api(write_options=SYNCHRONOUS)

# %%
# Function to import data from a CSV file to InfluxDB
def import_csv_to_influx(file_path, measurement):
    with open(file_path, 'r') as csv_file:
        csv_reader = csv.DictReader(csv_file)

        for row in csv_reader:

            volume = row.pop('Volume', None)

            # Convert the date string to a timestamp
            timestamp = int(datetime.strptime(row['Date'], '%Y-%m-%d').timestamp()) * 1000000000

            # Create an InfluxDB data point for each row
            data = Point(measurement).time(timestamp)

            # Iterate over each column in the row (excluding 'Date')
            for key, value in row.items():
                if key != 'Date':
                    # Convert non-date values to floats and add them as fields
                    data.field(key, float(value))

            # Write the data point to InfluxDB
            write_api.write(bucket=bucket, record=data, timeout=20)

# %%
import_csv_to_influx('Final_Dataset.csv', 'Factors')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import_csv_to_influx('Final_Dataset.csv', 'Factors')
#
# Cell In[4], line 20, in import_csv_to_influx(file_path, measurement)
#      17 for key, value in row.items():
#      18     if key != 'Date':
#      19         # Convert non-date values to floats and add them as fields
# ---> 20         data.field(key, float(value))
#      22 # Write the data point to InfluxDB
#      23 write_api.write(bucket=bucket, record=data, timeout=20)
#
# ValueError: could not convert string to float: ''

# %%
client.close()
