# %%
import pandas as pd

# %%
file_path = 'ECB Data Portal_20240109082607.csv'
csv = pd.read_csv(file_path)
csv.head()
# Out:
#          DATE TIME PERIOD  \
# 0  1994-01-31     1994Jan
# 1  1994-02-28     1994Feb
# 2  1994-03-31     1994Mar
# 3  1994-04-30     1994Apr
# 4  1994-05-31     1994May
#
#    Euribor 1-year - Historical close, average of observations through period (FM.M.U2.EUR.RT.MM.EURIBOR1YD_.HSTA)
# 0                                               6.34
# 1                                               6.42
# 2                                               6.55
# 3                                               6.46
# 4                                               6.25

# %%
csv = csv.drop(["TIME PERIOD"], axis=1)
csv.head()
# Out:
#          DATE  \
# 0  1994-01-31
# 1  1994-02-28
# 2  1994-03-31
# 3  1994-04-30
# 4  1994-05-31
#
#    Euribor 1-year - Historical close, average of observations through period (FM.M.U2.EUR.RT.MM.EURIBOR1YD_.HSTA)
# 0                                               6.34
# 1                                               6.42
# 2                                               6.55
# 3                                               6.46
# 4                                               6.25

# %%
output_csv_path = "Debt_daily_02.csv"
csv.to_csv(output_csv_path)
