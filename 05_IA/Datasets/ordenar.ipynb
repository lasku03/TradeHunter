# %%
import pandas as pd

# %%
path = 'Debt.csv'
df = pd.read_csv(path)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.sort_values(by='Date')
df.head()
# Out:
#             Date  Total_debt  Debt_GDP_percentage  Debt_per_capita
# 10227 1994-01-01    249508.0                58.68           6294.0
# 20819 1994-01-01    249508.0                58.68           6294.0
# 10228 1994-01-02    249508.0                58.68           6294.0
# 20820 1994-01-02    249508.0                58.68           6294.0
# 10229 1994-01-03    249508.0                58.68           6294.0

# %%
df.to_csv('Debt_finished.csv', index=False)
