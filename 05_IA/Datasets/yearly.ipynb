# %%
import pandas as pd
import calendar

# %%
file_path = 'series653292579c.csv'
df = pd.read_csv(file_path)
df = df.drop(['TIPO DATO'], axis=1)
dfs = []
df.head()
# Out:
#    PERIODO    VALOR
# 0     2022  329.251
# 1     2021  337.380
# 2     2020  341.315
# 3     2019  360.617
# 4     2018  372.777

# %%
for index, row in df.iterrows():
    year = int(row[0])
    valor = row[1] * 1000
    
    start_date = pd.to_datetime(f"{year}-01-01")
    end_date = pd.to_datetime(f"{year}-12-31")

    if calendar.isleap(year):
        valor = int(valor / 366)
    else:
        valor = int(valor / 365)
    
    date_range = pd.date_range(start=start_date, end=end_date, freq="D")

    temp_df = pd.DataFrame(
        {
            "Date": date_range,
            "Births": valor
        }
    )
    dfs.append(temp_df)
new_df = pd.concat(dfs, ignore_index=True)
new_df.drop_duplicates()
output_csv_path = "Births_daily.csv"
new_df.to_csv(output_csv_path)
# Out:
# C:\Users\julga\AppData\Local\Temp\ipykernel_7200\493959342.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   year = int(row[0])
# C:\Users\julga\AppData\Local\Temp\ipykernel_7200\493959342.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   valor = row[1] * 1000
