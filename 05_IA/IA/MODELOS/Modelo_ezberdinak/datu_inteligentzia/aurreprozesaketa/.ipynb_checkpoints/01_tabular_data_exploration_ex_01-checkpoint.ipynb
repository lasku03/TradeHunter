# %% [markdown]
# # 📝 Datu tabularrak ariketa

# %% [markdown]
# Imaginatu, pinguino desberdinen artean diferentziatzea nahi dogula, eta horretako: culmen length and culmen depth aldagaiak ditugula. egin dezagun datuen explorazioa:
#
# zeintzuk dira aldagaiak? zein da target-a?

# %% [markdown]
# kargatu datuak `../datasets/penguins_classification.csv`, `pandas`  `DataFrame` baten gorde dadin.

# %%
# KODEA HEMEN

# %% [markdown]
# Erakutsi errenkada edo obserbazio batzuk
# Zenbat dira numerikoak? zenbat kategorikoak?

# %%
# Write your code here.

# %% [markdown]
# Zenbat pinguino espezie desberdin daude dataset-ean? zenbat obserbazio dauzkagu pinguino desberdin bakoitzerako?
# [`value_counts`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html) metodoa erabili zenezake.

# %%
# Write your code here.

# %% [markdown]
# Ploteatu histogramak numerikoentzat

# %%
# Write your code here.

# %% [markdown]
# klase bakoitzarentzat histogramak ploteatu. erabili
# [`seaborn.pairplot`](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
# Write your code here.

# %% [markdown]
# Hau guztia begiratzen, zaila al da pinguinoak desberdintzea, bi aldaiak kontuta hartuta?
# ("culmen depth" and "culmen length")
