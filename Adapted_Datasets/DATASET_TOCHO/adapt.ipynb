# %%
import pandas as pd

# %%
df = pd.read_csv("IBEX-23_sorted.csv", parse_dates=['Date'])
df.head()
# Out:
#         Date    Open    High     Low   Close  AdjClose
# 0 2023-01-01  8229.1  8290.4  8221.7  8229.1    8229.1
# 1 2023-01-02  8297.9  8384.9  8283.7  8369.7    8369.7
# 2 2023-01-03  8366.9  8454.3  8327.4  8397.4    8397.4
# 3 2023-01-04  8443.1  8560.5  8442.1  8559.8    8559.8
# 4 2023-01-05  8530.2  8618.9  8527.7  8607.6    8607.6

# %%
df = df.drop(['Volume'], axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df = df.drop(['Volume'], axis=1)
#       2 df.head()
#
# File c:\Users\julga\anaconda3\envs\IA\lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
# ...

# %%
df.sort_values('Date', inplace=True)
date_range = pd.date_range(start=df['Date'].min(), end=df['Date'].max())
df.head()
# Out:
#         Date    Open    High     Low   Close  AdjClose
# 0 2023-01-01  8229.1  8290.4  8221.7  8229.1    8229.1
# 1 2023-01-02  8297.9  8384.9  8283.7  8369.7    8369.7
# 2 2023-01-03  8366.9  8454.3  8327.4  8397.4    8397.4
# 3 2023-01-04  8443.1  8560.5  8442.1  8559.8    8559.8
# 4 2023-01-05  8530.2  8618.9  8527.7  8607.6    8607.6

# %%
df = df.set_index('Date').reindex(date_range).rename_axis('Date').reset_index()
df.head()
# Out:
#         Date    Open    High     Low   Close  AdjClose
# 0 2023-01-01  8229.1  8290.4  8221.7  8229.1    8229.1
# 1 2023-01-02  8297.9  8384.9  8283.7  8369.7    8369.7
# 2 2023-01-03  8366.9  8454.3  8327.4  8397.4    8397.4
# 3 2023-01-04  8443.1  8560.5  8442.1  8559.8    8559.8
# 4 2023-01-05  8530.2  8618.9  8527.7  8607.6    8607.6

# %%
df.fillna(method='ffill', inplace=True)
df.head()
# Out:
# C:\Users\julga\AppData\Local\Temp\ipykernel_9708\2766238617.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
#         Date    Open    High     Low   Close  AdjClose
# 0 2023-01-01  8229.1  8290.4  8221.7  8229.1    8229.1
# 1 2023-01-02  8297.9  8384.9  8283.7  8369.7    8369.7
# 2 2023-01-03  8366.9  8454.3  8327.4  8397.4    8397.4
# 3 2023-01-04  8443.1  8560.5  8442.1  8559.8    8559.8
# 4 2023-01-05  8530.2  8618.9  8527.7  8607.6    8607.6

# %%
df.to_csv('IBEX-2023_updated.csv', index=False)
